# %% [markdown]
# # Economic Indicator Prediction - Example Notebook
#
# This notebook demonstrates how to use the Economic Indicator Prediction system for forecasting economic variables.
#
# **DISCLAIMER: This notebook is for RESEARCH AND EDUCATIONAL PURPOSES ONLY. This is NOT investment advice.**

# %%
# Import required libraries
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Add src to path
sys.path.append(str(Path.cwd() / 'src'))

# Import project modules
from utils import set_seed, setup_logging
from data import EconomicDataLoader, DataPreprocessor
from features import FeatureEngineer
from models import ModelFactory
from evaluation import ModelEvaluator
from risk import RiskManager

# Set random seed for reproducibility
set_seed(42)

# Setup logging
logger = setup_logging('INFO')
print("✅ Libraries imported successfully")
